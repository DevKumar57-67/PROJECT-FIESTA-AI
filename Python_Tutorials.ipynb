# %% [markdown]
# <a href="https://colab.research.google.com/github/DevKumar57-67/PROJECT-FIESTA-AI/blob/main/Python_Tutorials.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# THIS NOTEBOOK CONTAINS COMPLETE PYTHON PROGRAMMING LANGUAGE TUTORIALS DIVIDED IN THREE PARTS
# PYTHON BASICS
# PYTHON INTERMEDIATE
# PYTHON ADVANCED

# %% [markdown]
# #        PYTHON BASICS

# %%
# Python syntax
print("HELLO DEV")
print("This is python programming language")
print("Python is a versatile programming language used for multipurpose ")
# Out:
# HELLO DEV
# This is python programming language
# Python is a versatile programming language used for multipurpose

# %%
# Comments in python
# THis is a single line comment in python
''' THIS is
a multiline comment in python '''

# %%
# Input / Output in python
x = input("Enter your Name ")
print("Hello", x)

# input is used for taking a string datype input from the user
# Out:
# Enter your Name Dev
# Hello Dev
